# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
import pickle
import tensorflow as tf 
from tensorflow.keras.models import load_model

# %%
##Load the trained model ANN ,column
model=load_model('model.h5')

#load the encoders
with open("gender_encoder.pkl",'rb') as file:
    label_encode_gen=pickle.load(file)

with open("preprocessor.pkl",'rb') as file:
    preprocessor=pickle.load(file)
# Out:
# WARNING:tensorflow:From c:\Users\ojass\OneDrive\Desktop\Udemy\DeepLearning\ANN\venvDL\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Example input data
input_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
input_df=pd.DataFrame([input_data])

# %%
input_df['Gender']=label_encode_gen.transform(input_df['Gender'])

# %%
input_processed=preprocessor.transform(input_df)

# %%
input_processed
# Out:
# array([[ 0.        ,  0.        , -0.53598516,  0.10479359, -0.69539349,
#         -0.25781119,  0.80843615, -0.87683221,  1.        ,  1.        ,
#          1.        ]])

# %%
prediction=model.predict(input_processed)
# Out:
# 1/1 [==============================] - 0s 137ms/step

# %%
prediction
# Out:
# array([[0.05816464]], dtype=float32)

# %%
prediction_proba=prediction[0][0]

# %%
prediction_proba
# Out:
# 0.05816464

# %%
if prediction_proba > 0.5:
    print('The Customer is likely to churn ')

else:
    print("The customer is not likely to churn")
# Out:
# The customer is not likely to churn
